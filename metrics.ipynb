# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data for metrics of different algorithms
data = {
    'Area': ['Kwashieman', 'Kwashieman', 'Kwashieman', 'Kwashieman', 'Kwashieman', 'Kwashieman',
             'Kawukudi', 'Kawukudi', 'Kawukudi', 'Kawukudi', 'Kawukudi', 'Kawukudi',
             'Kanda', 'Kanda', 'Kanda', 'Kanda', 'Kanda', 'Kanda',
             'Dansoman', 'Dansoman', 'Dansoman', 'Dansoman', 'Dansoman', 'Dansoman',
             'Korle Bu', 'Korle Bu', 'Korle Bu', 'Korle Bu', 'Korle Bu', 'Korle Bu'],
    'Algorithm': ['Linear Regression', 'Lasso Regression', 'Ridge', 'SVR', 'RFR', 'CBR',
                  'Linear Regression', 'Lasso Regression', 'Ridge', 'SVR', 'RFR', 'CBR',
                  'Linear Regression', 'Lasso Regression', 'Ridge', 'SVR', 'RFR', 'CBR',
                  'Linear Regression', 'Lasso Regression', 'Ridge', 'SVR', 'RFR', 'CBR',
                  'Linear Regression', 'Lasso Regression', 'Ridge', 'SVR', 'RFR', 'CBR'],
    'R2_Score': [0.927621443846536,  0.9158344551297848, 0.9158345027566057, 0.9788300619701336, 0.9999876892991643, 0.9995028591329778,
                 0.8838887498855786, 0.8860554357092398, 0.8860554742500467, 0.9680248570848399, 0.9999484550298232, 0.9993405530899452,
                 0.9435490127779145, 0.945730029647428, 0.9457300848730134, 0.9808600526844365, 0.9999270183258855, 0.9991288749195645,
                 0.9455064901455041, 0.9311456387468716, 0.9311456658702624, 0.9936168512056671, 0.9999896753545884, 0.9995969283741881,
                 0.9340878367785608, 0.9377587188989701,0.9377588255262119, 0.9965143637151344
, 0.9999645797388915, 0.9992673115390497],
   # 'MAE': [6.707104309862716, 6.826773237056984, 6.825357819254396, 0.805984902747304, 0.023258138938733658, 0.28364780080594915,
    #        7.862839294446745, 7.826259318121211, 7.824889377537373, 1.0097516754663294, 0.041480547550432276, 0.33263028455279176,
     #       4.886953977041467, 4.954599126595955, 4.9537609728983965, 0.7681210511494685, 0.03359328726554787, 0.3057853785554523,
      #      6.363330489310084, 6.482774414116794, 6.481240666395285, 0.7713866178943424, 0.02624141315014725, 0.29465456073158847,
       #     4.530715445023383, 4.592171808281975, 4.590818752901138, 0.5574496631925508, 0.03644521739130434, 0.3249313871711166],
  #'RMSE': [9.771754634109564, 10.657030198875171, 10.657027183623846, 5.284785796553701, 0.12744094540412038, 0.8098551130528989,
   #         12.824918463852207, 12.7064675083764, 12.706465359447424, 6.730133970049667, 0.270215718606695, 0.9665122905615247,
    #         8.198908029339757, 8.176841279394582, 8.176837118981766, 4.7740901225758705, 0.2947997797960818, 1.0184987560882843,
    #        8.606686630074307, 9.690901142412994, 9.690899233673159, 2.9456496002803756, 0.11846803162668318, 0.7402096004519085,
    #        8.829783078706512, 8.73009641577686, 8.730088937890125, 2.030524741672086, 0.20468835271976377, 0.9309512249165788
    }

# Convert data to DataFrame
df = pd.DataFrame(data)

# Set the style of the visualization
sns.set(style="whitegrid")

# Initialize the figure
plt.figure(figsize=(14, 18))

# Plot R2_Score
plt.subplot(3, 1, 1)
sns.barplot(x='Area', y='R2_Score', hue='Algorithm', data=df, palette='muted')
plt.title('R2 Score by Algorithm and Area')
plt.legend(loc='center')

# Plot MAE
#plt.subplot(3, 1, 2)
#sns.barplot(x='Area', y='MAE', hue='Algorithm', data=df, palette='muted')
#plt.title('Mean Absolute Error (MAE) by Algorithm and Area')
#plt.legend(loc='upper right')

# Plot RMSE
#plt.subplot(3, 1, 3)
#sns.barplot(x='Area', y='RMSE', hue='Algorithm', data=df, palette='muted')
#plt.title('Root Mean Square Error (RMSE) by Algorithm and Area')
#plt.legend(loc='upper right')

# Adjust layout
plt.tight_layout()
plt.show()
